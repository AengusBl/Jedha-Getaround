# %%
import pandas as pd

pricing_df = pd.read_csv("https://full-stack-assets.s3.eu-west-3.amazonaws.com/Deployment/get_around_pricing_project.csv", index_col=0)
pricing_df.head()
# Out:
#   model_key  mileage  engine_power    fuel paint_color     car_type  \
# 0   Citroën   140411           100  diesel       black  convertible
# 1   Citroën    13929           317  petrol        grey  convertible
# 2   Citroën   183297           120  diesel       white  convertible
# 3   Citroën   128035           135  diesel         red  convertible
# 4   Citroën    97097           160  diesel      silver  convertible
#
#    private_parking_available  has_gps  has_air_conditioning  automatic_car  \
# 0                       True     True                 False          False
# 1                       True     True                 False          False
# 2                      False    False                 False          False
# 3                       True     True                 False          False
# 4                       True     True                 False          False
#
#    has_getaround_connect  has_speed_regulator  winter_tires  \
# 0                   True                 True          True
# 1                  False                 True          True
# 2                   True                False          True
# 3                   True                 True          True
# 4                  False                 True          True
#
#    rental_price_per_day
# 0                   106
# 1                   264
# 2                   101
# 3                   158
# 4                   183

# %%
params_list = [i/2000 for i in range(1, 100)]
params_list[:10]
# Out:
# [0.0005, 0.001, 0.0015, 0.002, 0.0025, 0.003, 0.0035, 0.004, 0.0045, 0.005]

# %%
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import OneHotEncoder, StandardScaler
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.linear_model import Ridge, Lasso
from sklearn.metrics import r2_score, make_scorer
from dotenv import load_dotenv
import pandas as pd
import mlflow
import joblib
import os

load_dotenv()

categorical_cols = ["model_key", "fuel", "paint_color", "car_type", "private_parking_available", "has_gps", "has_air_conditioning",
                    "automatic_car", "has_getaround_connect", "has_speed_regulator", "winter_tires"]
numerical_cols = ["mileage", "engine_power"]

X = pricing_df[categorical_cols + numerical_cols]
y = pricing_df["rental_price_per_day"]

bins = pd.qcut(y, q=4, duplicates="drop")
X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    train_size=0.75,
    random_state=444719,
    stratify=bins
)

onehot_encoder = OneHotEncoder(drop="first", handle_unknown="ignore")
standard_scaler = StandardScaler()

preprocessor = ColumnTransformer(
    transformers=[
        ("categorical", onehot_encoder, categorical_cols),
        ("numerical", standard_scaler, numerical_cols)
    ]
)

model = Lasso()  # or Ridge()

pipeline = Pipeline(steps=[
    ("preprocessor", preprocessor),
    ("regressor", model)
])

param_grid = {
    "regressor__alpha": params_list
}

scorer = make_scorer(r2_score)

grid_search = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    cv=5,
    scoring=scorer,
    n_jobs=-1
)

EXPERIMENT_NAME="getaround-price-prediction"
mlflow.set_tracking_uri(os.environ["TRACKING_SERVER_URL"])
mlflow.set_experiment(EXPERIMENT_NAME)
experiment = mlflow.get_experiment_by_name(EXPERIMENT_NAME)

with mlflow.start_run(experiment_id = experiment.experiment_id, run_name="Lasso_GridSearchCV_1_casting_a_wide_net"):
    grid_search.fit(X_train, y_train)

    mlflow.log_params(grid_search.best_params_)

    y_pred = grid_search.predict(X_test)
    r2 = r2_score(y_test, y_pred)

    mlflow.log_metric("test_r2", r2)

    print("Best parameters:", grid_search.best_params_)
    print("Best cross-validation R²:", grid_search.best_score_)
    print("Test R²:", r2)

    input_example = X_train.iloc[:1]
    mlflow.sklearn.log_model(
        grid_search.best_estimator_,
        "model",
        input_example=input_example,
        registered_model_name="getaround-price-prediction-model"
    )

    # joblib.dump(grid_search.best_estimator_, "linear_regression_model.pkl")
# Out:
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 2532.157145146397, tolerance: 319.3948240880937
#   model = cd_fast.sparse_enet_coordinate_descent(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 14462.419849986443, tolerance: 317.08117349397594
#   model = cd_fast.sparse_enet_coordinate_descent(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16738.78938392189, tolerance: 324.3607906400553
#   model = cd_fast.sparse_enet_coordinate_descent(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 16449.70028180012, tolerance: 331.0696879903649
#   model = cd_fast.sparse_enet_coordinate_descent(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 1907.4732211203082, tolerance: 319.3948240880937
#   model = cd_fast.sparse_enet_coordinate_descent(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/linear_model/_coordinate_descent.py:656: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 483.96437688404694, tolerance: 319.3948240880937
#   model = cd_fast.sparse_enet_coordinate_descent(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# ...
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/sklearn/preprocessing/_encoders.py:246: UserWarning: Found unknown categories in columns [0] during transform. These unknown categories will be encoded as all zeros
#   warnings.warn(
# Best parameters: {'regressor__alpha': 0.0085}
# Best cross-validation R²: 0.6961471561171957
# Test R²: 0.7020558138674361
# /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/mlflow/types/utils.py:452: UserWarning: Hint: Inferred schema contains integer column(s). Integer columns in Python cannot represent missing values. If your input data contains missing values at inference time, it will be encoded as floats and will cause a schema enforcement error. The best way to avoid this problem is to infer the model schema based on a realistic data sample (training dataset) that includes missing values. Alternatively, you can declare integer columns as doubles (float64) whenever these columns may have missing values. See `Handling Integers With Missing Values <https://www.mlflow.org/docs/latest/models.html#handling-integers-with-missing-values>`_ for more details.
#   warnings.warn(
# Registered model 'getaround-price-prediction-model' already exists. Creating a new version of this model...
# 2025/08/18 19:06:15 INFO mlflow.store.model_registry.abstract_store: Waiting up to 300 seconds for model version to finish creation. Model name: getaround-price-prediction-model, version 17
# Created version '17' of model 'getaround-price-prediction-model'.
# 🏃 View run Lasso_GridSearchCV_1_casting_a_wide_net at: https://aengusbl-getaround-mlflow.hf.space/#/experiments/2/runs/0d5aa87039d84e7a905702b75b770c27
# 🧪 View experiment at: https://aengusbl-getaround-mlflow.hf.space/#/experiments/2
# Exception ignored in: <function ResourceTracker.__del__ at 0x103251300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x109979300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10ead9300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x104525300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x107879300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x110a31300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10bb3d300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10bc71300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10f80d300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10d491300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x107811300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x104189300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10d0f9300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x1069f5300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x10cfb1300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes
# Exception ignored in: <function ResourceTracker.__del__ at 0x106e49300>
# Traceback (most recent call last):
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 77, in __del__
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 86, in _stop
#   File "/opt/anaconda3/envs/mlflow_env/lib/python3.12/multiprocessing/resource_tracker.py", line 111, in _stop_locked
# ChildProcessError: [Errno 10] No child processes

# %%
# This cell tests the model, with an input example that was part of the logs sent to the tracking server
import mlflow
from mlflow.models import Model
from dotenv import load_dotenv

load_dotenv()

model_uri = 's3://getaround-mlflow-artifactstore/2/b21d60925615456587e03b92d95843c4/artifacts/model'

pyfunc_model = mlflow.pyfunc.load_model(model_uri)
input_data = pyfunc_model.input_example

mlflow.models.predict(
    model_uri=model_uri,
    input_data=input_data,
    env_manager="conda",
)
# Out:
# 2025/08/18 19:16:53 INFO mlflow.models.python_api: It is highly recommended to use `uv` as the environment manager for predicting with MLflow models as its performance is significantly better than other environment managers. Run `pip install uv` to install uv. See https://docs.astral.sh/uv/getting-started/installation for other installation methods.
# 2025/08/18 19:16:53 INFO mlflow.models.flavor_backend_registry: Selected backend for flavor 'python_function'
# 2025/08/18 19:16:56 INFO mlflow.utils.conda: === Creating conda environment /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpbuo87apc/envs/conda_envs/mlflow-c73ae8786f87d613ef17c0fe652494c39f6dff36-8f29c64111ad37fd5ede73b43578e91380b4e0f0 ===
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# python-3.12.11       | 12.9 MB   |            |   0%
# tk-8.6.13            | 3.1 MB    |            |   0%
#
# openssl-3.5.2        | 2.6 MB    |            |   0%
#
#
# pip-25.1             | 1.2 MB    |            |   0%
#
#
#
# libsqlite-3.50.4     | 957 KB    |            |   0%
#
#
#
#
# ncurses-6.5          | 803 KB    |            |   0%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    |            |   0%
#
#
#
#
#
#
# readline-8.2         | 251 KB    |            |   0%
#
#
#
#
#
#
#
# ca-certificates-2025 | 151 KB    |            |   0%
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 131 KB    |            |   0%
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 102 KB    |            |   0%
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 71 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 61 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 56 KB     |            |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 50 KB     |            |   0%
# python-3.12.11       | 12.9 MB   |            |   0%
#
# openssl-3.5.2        | 2.6 MB    |            |   1%
#
#
# pip-25.1             | 1.2 MB    | 1          |   1%
#
#
#
# python-3.12.11       | 12.9 MB   | 1          |   1%
#
#
# pip-25.1             | 1.2 MB    | #          |  11%
#
#
#
# libsqlite-3.50.4     | 957 KB    | 5          |   5%
# tk-8.6.13            | 3.1 MB    | 4          |   4%
#
#
#
# libsqlite-3.50.4     | 957 KB    | #6         |  17%
#
# openssl-3.5.2        | 2.6 MB    | 4          |   5%
#
#
# pip-25.1             | 1.2 MB    | #4         |  14%
#
# openssl-3.5.2        | 2.6 MB    | #6         |  16%
#
#
#
# python-3.12.11       | 12.9 MB   | 3          |   4%
# tk-8.6.13            | 3.1 MB    | #1         |  11%
#
#
# python-3.12.11       | 12.9 MB   | 6          |   7%
# tk-8.6.13            | 3.1 MB    | #2         |  13%
#
#
#
# libsqlite-3.50.4     | 957 KB    | ####5      |  45%
#
# openssl-3.5.2        | 2.6 MB    | ##         |  21%
#
#
# python-3.12.11       | 12.9 MB   | #          |  11%
#
# openssl-3.5.2        | 2.6 MB    | ##9        |  29%
# tk-8.6.13            | 3.1 MB    | ###2       |  32%
#
#
#
# libsqlite-3.50.4     | 957 KB    | #####5     |  55%
#
#
# pip-25.1             | 1.2 MB    | ####2      |  42%
#
#
# python-3.12.11       | 12.9 MB   | #2         |  13%
#
#
#
# libsqlite-3.50.4     | 957 KB    | ######1    |  62%
#
#
#
# python-3.12.11       | 12.9 MB   | #4         |  15%
# tk-8.6.13            | 3.1 MB    | ###7       |  38%
#
# openssl-3.5.2        | 2.6 MB    | ###4       |  34%
#
#
# pip-25.1             | 1.2 MB    | #####5     |  55%
#
#
# pip-25.1             | 1.2 MB    | ######     |  60%
#
# python-3.12.11       | 12.9 MB   | #6         |  16%
#
#
#
# libsqlite-3.50.4     | 957 KB    | #######5   |  75%
# python-3.12.11       | 12.9 MB   | #9         |  20%
#
# openssl-3.5.2        | 2.6 MB    | ####4      |  45%
#
#
# pip-25.1             | 1.2 MB    | #######4   |  75%
#
#
#
# libsqlite-3.50.4     | 957 KB    | ########6  |  87%
# python-3.12.11       | 12.9 MB   | ##1        |  22%
#
# openssl-3.5.2        | 2.6 MB    | ####8      |  49%
#
#
#
# libsqlite-3.50.4     | 957 KB    | #########3 |  94%
#
#
# pip-25.1             | 1.2 MB    | ########2  |  83%
#
#
#
# libsqlite-3.50.4     | 957 KB    | ########## | 100%
# tk-8.6.13            | 3.1 MB    | #####      |  51%
#
#
#
# python-3.12.11       | 12.9 MB   | ##3        |  24%
#
# openssl-3.5.2        | 2.6 MB    | #####3     |  53%
#
#
# pip-25.1             | 1.2 MB    | ########9  |  89%
#
#
#
# python-3.12.11       | 12.9 MB   | ##5        |  25%
#
#
# pip-25.1             | 1.2 MB    | #########5 |  96%
# tk-8.6.13            | 3.1 MB    | #####4     |  54%
#
# openssl-3.5.2        | 2.6 MB    | #####7     |  57%
#
#
#
#
# ncurses-6.5          | 803 KB    | 1          |   2%
#
#
# python-3.12.11       | 12.9 MB   | ##7        |  27%
#
# openssl-3.5.2        | 2.6 MB    | ######     |  61%
# tk-8.6.13            | 3.1 MB    | #####7     |  57%
#
#
#
#
# python-3.12.11       | 12.9 MB   | ##8        |  29%
#
# openssl-3.5.2        | 2.6 MB    | ######4    |  64%
#
#
#
#
# ncurses-6.5          | 803 KB    | #7         |  18%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | 2          |   2%
# python-3.12.11       | 12.9 MB   | ###        |  30%
#
# openssl-3.5.2        | 2.6 MB    | ######8    |  68%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | #          |  11%
#
#
# pip-25.1             | 1.2 MB    | ########## | 100%
#
#
#
#
# ncurses-6.5          | 803 KB    | ##5        |  26%
# python-3.12.11       | 12.9 MB   | ###1       |  32%
#
# openssl-3.5.2        | 2.6 MB    | #######1   |  72%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | ##4        |  24%
#
#
#
#
# ncurses-6.5          | 803 KB    | ###5       |  36%
# python-3.12.11       | 12.9 MB   | ###3       |  33%
#
# openssl-3.5.2        | 2.6 MB    | #######5   |  75%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | ###2       |  33%
#
#
#
#
# ncurses-6.5          | 803 KB    | ####3      |  44%
# python-3.12.11       | 12.9 MB   | ###4       |  35%
#
# openssl-3.5.2        | 2.6 MB    | #######8   |  79%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | ####3      |  44%
#
#
#
#
# ncurses-6.5          | 803 KB    | #####1     |  52%
# python-3.12.11       | 12.9 MB   | ###6       |  36%
#
# openssl-3.5.2        | 2.6 MB    | ########2  |  82%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | #####4     |  55%
#
#
#
#
# python-3.12.11       | 12.9 MB   | ###7       |  38%
# tk-8.6.13            | 3.1 MB    | #######2   |  73%
#
# openssl-3.5.2        | 2.6 MB    | ########5  |  86%
#
#
#
#
#
# python-3.12.11       | 12.9 MB   | ###9       |  39%
#
#
#
#
# ncurses-6.5          | 803 KB    | ######7    |  68%
# tk-8.6.13            | 3.1 MB    | #######5   |  75%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | #######6   |  77%
#
# openssl-3.5.2        | 2.6 MB    | ########9  |  90%
#
#
#
#
# python-3.12.11       | 12.9 MB   | ####       |  40%
# tk-8.6.13            | 3.1 MB    | #######7   |  78%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | ########7  |  88%
#
# python-3.12.11       | 12.9 MB   | ####1      |  42%
#
#
#
#
# ncurses-6.5          | 803 KB    | ########5  |  86%
# tk-8.6.13            | 3.1 MB    | ########   |  80%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | #########8 |  98%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | ########## | 100%
#
# python-3.12.11       | 12.9 MB   | ####3      |  43%
#
#
#
#
# ncurses-6.5          | 803 KB    | #########5 |  96%
# tk-8.6.13            | 3.1 MB    | ########2  |  83%
#
# openssl-3.5.2        | 2.6 MB    | ########## | 100%
#
# openssl-3.5.2        | 2.6 MB    | ########## | 100%
#
#
#
#
# python-3.12.11       | 12.9 MB   | ####4      |  45%
#
#
#
#
#
#
# readline-8.2         | 251 KB    | 6          |   6%
# python-3.12.11       | 12.9 MB   | ####6      |  46%
#
#
#
#
#
#
# readline-8.2         | 251 KB    | ####4      |  45%
#
#
#
#
#
#
#
# ca-certificates-2025 | 151 KB    | #          |  11%
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 131 KB    | #2         |  12%
# python-3.12.11       | 12.9 MB   | ####7      |  47%
#
#
#
#
#
#
#
# ca-certificates-2025 | 151 KB    | ####2      |  42%
#
# openssl-3.5.2        | 2.6 MB    | ########## | 100%
#
#
#
#
#
#
# readline-8.2         | 251 KB    | #######    |  70%
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 131 KB    | ####8      |  49%
#
#
#
#
#
# setuptools-80.9.0    | 731 KB    | ########## | 100%
#
#
#
#
#
#
#
# ca-certificates-2025 | 151 KB    | #######4   |  74%
# python-3.12.11       | 12.9 MB   | ####8      |  49%
#
#
#
#
#
#
# readline-8.2         | 251 KB    | #########5 |  96%
#
#
#
#
#
#
# readline-8.2         | 251 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 131 KB    | ########5  |  85%
#
#
#
#
#
#
#
# ca-certificates-2025 | 151 KB    | ########## | 100%
#
#
#
#
#
#
#
#
# bzip2-1.0.8          | 131 KB    | ########## | 100%
#
#
#
#
#
#
#
# ca-certificates-2025 | 151 KB    | ########## | 100%
#
#
#
#
#
#
# readline-8.2         | 251 KB    | ########## | 100%
# tk-8.6.13            | 3.1 MB    | #########3 |  93%
#
#
#
#
#
#
#
#
# python-3.12.11       | 12.9 MB   | #####      |  50%
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | #3         |  13%
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 102 KB    | #5         |  16%
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.11       | 12.9 MB   | #####1     |  52%
# tk-8.6.13            | 3.1 MB    | #########5 |  96%
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 102 KB    | #######8   |  78%
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | ######6    |  67%
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 102 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
# liblzma-5.8.1        | 102 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 71 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# libexpat-2.7.1       | 71 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.11       | 12.9 MB   | #####3     |  53%
# tk-8.6.13            | 3.1 MB    | #########9 |  99%
# tk-8.6.13            | 3.1 MB    | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 61 KB     | ##6        |  26%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.11       | 12.9 MB   | #####4     |  55%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 56 KB     | ##8        |  29%
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 50 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.11       | 12.9 MB   | ######1    |  62%
#
#
#
#
#
#
#
#
#
# tzdata-2025b         | 120 KB    | ########## | 100%
#
#
#
#
#
#
#
#
#
# python-3.12.11       | 12.9 MB   | ######3    |  63%
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# wheel-0.45.1         | 61 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 50 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libffi-3.4.6         | 50 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libzlib-1.3.1        | 56 KB     | ########## | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.12.11       | 12.9 MB   | ######4    |  65%
# python-3.12.11       | 12.9 MB   | #######3   |  73%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                                       done
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
# Installing pip dependencies: \ Ran pip subprocess with arguments:
# ['/var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpbuo87apc/envs/conda_envs/mlflow-c73ae8786f87d613ef17c0fe652494c39f6dff36-8f29c64111ad37fd5ede73b43578e91380b4e0f0/bin/python', '-m', 'pip', 'install', '-U', '-r', '/var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt', '--exists-action=b']
# Pip subprocess output:
# Collecting mlflow==2.21.3 (from -r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading mlflow-2.21.3-py3-none-any.whl.metadata (30 kB)
# Collecting cloudpickle==3.1.1 (from -r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 2))
#   Downloading cloudpickle-3.1.1-py3-none-any.whl.metadata (7.1 kB)
# Collecting numpy==2.3.1 (from -r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 3))
#   Downloading numpy-2.3.1-cp312-cp312-macosx_14_0_x86_64.whl.metadata (62 kB)
# Collecting pandas==2.3.0 (from -r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 4))
#   Downloading pandas-2.3.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (91 kB)
# Collecting psutil==5.9.0 (from -r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 5))
#   Downloading psutil-5.9.0.tar.gz (478 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn==1.6.1 (from -r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 6))
#   Downloading scikit_learn-1.6.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (31 kB)
# Collecting scipy==1.16.0 (from -r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 7))
#   Downloading scipy-1.16.0-cp312-cp312-macosx_14_0_x86_64.whl.metadata (61 kB)
# Collecting mlflow-skinny==2.21.3 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading mlflow_skinny-2.21.3-py3-none-any.whl.metadata (31 kB)
# Collecting Flask<4 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading flask-3.1.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting Jinja2<4,>=2.11 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting alembic!=1.10.0,<2 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading alembic-1.16.4-py3-none-any.whl.metadata (7.3 kB)
# Collecting docker<8,>=4.0.0 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Collecting markdown<4,>=3.3 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading markdown-3.8.2-py3-none-any.whl.metadata (5.1 kB)
# Collecting matplotlib<4 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading matplotlib-3.10.5-cp312-cp312-macosx_10_13_x86_64.whl.metadata (11 kB)
# Collecting pyarrow<20,>=4.0.0 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading pyarrow-19.0.1-cp312-cp312-macosx_12_0_x86_64.whl.metadata (3.3 kB)
# Collecting sqlalchemy<3,>=1.4.0 (from mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading sqlalchemy-2.0.43-cp312-cp312-macosx_10_13_x86_64.whl.metadata (9.6 kB)
# Collecting python-dateutil>=2.8.2 (from pandas==2.3.0->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 4))
#   Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl.metadata (8.4 kB)
# Collecting pytz>=2020.1 (from pandas==2.3.0->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 4))
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas==2.3.0->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 4))
#   Downloading tzdata-2025.2-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting joblib>=1.2.0 (from scikit-learn==1.6.1->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 6))
#   Downloading joblib-1.5.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn==1.6.1->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 6))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting cachetools<6,>=5.0.0 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading cachetools-5.5.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting click<9,>=7.0 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading click-8.2.1-py3-none-any.whl.metadata (2.5 kB)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading databricks_sdk-0.63.0-py3-none-any.whl.metadata (39 kB)
# Collecting fastapi<1 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading fastapi-0.116.1-py3-none-any.whl.metadata (28 kB)
# Collecting gitpython<4,>=3.1.9 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading gitpython-3.1.45-py3-none-any.whl.metadata (13 kB)
# Collecting importlib_metadata!=4.7.0,<9,>=3.7.0 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading importlib_metadata-8.7.0-py3-none-any.whl.metadata (4.8 kB)
# Collecting opentelemetry-api<3,>=1.9.0 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading opentelemetry_api-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting opentelemetry-sdk<3,>=1.9.0 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl.metadata (1.5 kB)
# Collecting packaging<25 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading packaging-24.2-py3-none-any.whl.metadata (3.2 kB)
# Collecting protobuf<6,>=3.12.0 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pydantic<3,>=1.10.8 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading pydantic-2.11.7-py3-none-any.whl.metadata (67 kB)
# Collecting pyyaml<7,>=5.1 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading PyYAML-6.0.2-cp312-cp312-macosx_10_9_x86_64.whl.metadata (2.1 kB)
# Collecting requests<3,>=2.17.3 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading requests-2.32.4-py3-none-any.whl.metadata (4.9 kB)
# Collecting sqlparse<1,>=0.4.0 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading sqlparse-0.5.3-py3-none-any.whl.metadata (3.9 kB)
# Collecting typing-extensions<5,>=4.0.0 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading typing_extensions-4.14.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting uvicorn<1 (from mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading uvicorn-0.35.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading mako-1.3.10-py3-none-any.whl.metadata (2.9 kB)
# Collecting google-auth~=2.0 (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading google_auth-2.40.3-py2.py3-none-any.whl.metadata (6.2 kB)
# Collecting urllib3>=1.26.0 (from docker<8,>=4.0.0->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading urllib3-2.5.0-py3-none-any.whl.metadata (6.5 kB)
# Collecting starlette<0.48.0,>=0.40.0 (from fastapi<1->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading starlette-0.47.2-py3-none-any.whl.metadata (6.2 kB)
# Collecting blinker>=1.9.0 (from Flask<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading blinker-1.9.0-py3-none-any.whl.metadata (1.6 kB)
# Collecting itsdangerous>=2.2.0 (from Flask<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading itsdangerous-2.2.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting markupsafe>=2.1.1 (from Flask<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading MarkupSafe-3.0.2-cp312-cp312-macosx_10_13_universal2.whl.metadata (4.0 kB)
# Collecting werkzeug>=3.1.0 (from Flask<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading werkzeug-3.1.3-py3-none-any.whl.metadata (3.7 kB)
# Collecting gitdb<5,>=4.0.1 (from gitpython<4,>=3.1.9->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading gitdb-4.0.12-py3-none-any.whl.metadata (1.2 kB)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading smmap-5.0.2-py3-none-any.whl.metadata (4.3 kB)
# Collecting pyasn1-modules>=0.2.1 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading pyasn1_modules-0.4.2-py3-none-any.whl.metadata (3.5 kB)
# Collecting rsa<5,>=3.1.4 (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading rsa-4.9.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Collecting zipp>=3.20 (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading zipp-3.23.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading contourpy-1.3.3-cp312-cp312-macosx_10_13_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading fonttools-4.59.1-cp312-cp312-macosx_10_13_x86_64.whl.metadata (108 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading kiwisolver-1.4.9-cp312-cp312-macosx_10_13_x86_64.whl.metadata (6.3 kB)
# Collecting pillow>=8 (from matplotlib<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading pillow-11.3.0-cp312-cp312-macosx_10_13_x86_64.whl.metadata (9.0 kB)
# Collecting pyparsing>=2.3.1 (from matplotlib<4->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading pyparsing-3.2.3-py3-none-any.whl.metadata (5.0 kB)
# Collecting opentelemetry-semantic-conventions==0.57b0 (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl.metadata (2.4 kB)
# Collecting annotated-types>=0.6.0 (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading annotated_types-0.7.0-py3-none-any.whl.metadata (15 kB)
# Collecting pydantic-core==2.33.2 (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading pydantic_core-2.33.2-cp312-cp312-macosx_10_12_x86_64.whl.metadata (6.8 kB)
# Collecting typing-inspection>=0.4.0 (from pydantic<3,>=1.10.8->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading typing_inspection-0.4.1-py3-none-any.whl.metadata (2.6 kB)
# Collecting six>=1.5 (from python-dateutil>=2.8.2->pandas==2.3.0->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 4))
#   Downloading six-1.17.0-py2.py3-none-any.whl.metadata (1.7 kB)
# Collecting charset_normalizer<4,>=2 (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading charset_normalizer-3.4.3-cp312-cp312-macosx_10_13_universal2.whl.metadata (36 kB)
# Collecting idna<4,>=2.5 (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading idna-3.10-py3-none-any.whl.metadata (10 kB)
# Collecting certifi>=2017.4.17 (from requests<3,>=2.17.3->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading certifi-2025.8.3-py3-none-any.whl.metadata (2.4 kB)
# Collecting pyasn1>=0.1.3 (from rsa<5,>=3.1.4->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading pyasn1-0.6.1-py3-none-any.whl.metadata (8.4 kB)
# Collecting greenlet>=1 (from sqlalchemy<3,>=1.4.0->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading greenlet-3.2.4-cp312-cp312-macosx_11_0_universal2.whl.metadata (4.1 kB)
# Collecting anyio<5,>=3.6.2 (from starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading anyio-4.10.0-py3-none-any.whl.metadata (4.0 kB)
# Collecting sniffio>=1.1 (from anyio<5,>=3.6.2->starlette<0.48.0,>=0.40.0->fastapi<1->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading sniffio-1.3.1-py3-none-any.whl.metadata (3.9 kB)
# Collecting h11>=0.8 (from uvicorn<1->mlflow-skinny==2.21.3->mlflow==2.21.3->-r /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model/condaenv.j6lufvhb.requirements.txt (line 1))
#   Downloading h11-0.16.0-py3-none-any.whl.metadata (8.3 kB)
# Downloading mlflow-2.21.3-py3-none-any.whl (28.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.2/28.2 MB 4.6 MB/s eta 0:00:0000:0100:01mm
# Downloading numpy-2.3.1-cp312-cp312-macosx_14_0_x86_64.whl (6.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 4.3 MB/s eta 0:00:00a 0:00:01
# Downloading pandas-2.3.0-cp312-cp312-macosx_10_13_x86_64.whl (11.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 4.6 MB/s eta 0:00:00a 0:00:01m
# Downloading scikit_learn-1.6.1-cp312-cp312-macosx_10_13_x86_64.whl (12.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.1/12.1 MB 4.5 MB/s eta 0:00:00a 0:00:01
# Downloading scipy-1.16.0-cp312-cp312-macosx_14_0_x86_64.whl (23.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.4/23.4 MB 4.6 MB/s eta 0:00:0000:0100:01m
# Downloading cloudpickle-3.1.1-py3-none-any.whl (20 kB)
# Downloading mlflow_skinny-2.21.3-py3-none-any.whl (6.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.1/6.1 MB 4.5 MB/s eta 0:00:00a 0:00:01m
# Downloading alembic-1.16.4-py3-none-any.whl (247 kB)
# Downloading cachetools-5.5.2-py3-none-any.whl (10 kB)
# Downloading click-8.2.1-py3-none-any.whl (102 kB)
# Downloading databricks_sdk-0.63.0-py3-none-any.whl (688 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 688.0/688.0 kB 3.9 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
# Downloading fastapi-0.116.1-py3-none-any.whl (95 kB)
# Downloading flask-3.1.1-py3-none-any.whl (103 kB)
# Downloading gitpython-3.1.45-py3-none-any.whl (208 kB)
# Downloading gitdb-4.0.12-py3-none-any.whl (62 kB)
# Downloading google_auth-2.40.3-py2.py3-none-any.whl (216 kB)
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
# Downloading importlib_metadata-8.7.0-py3-none-any.whl (27 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markdown-3.8.2-py3-none-any.whl (106 kB)
# Downloading matplotlib-3.10.5-cp312-cp312-macosx_10_13_x86_64.whl (8.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━��━━━━━ 8.3/8.3 MB 4.8 MB/s eta 0:00:00 0:00:01
# Downloading opentelemetry_api-1.36.0-py3-none-any.whl (65 kB)
# Downloading opentelemetry_sdk-1.36.0-py3-none-any.whl (119 kB)
# Downloading opentelemetry_semantic_conventions-0.57b0-py3-none-any.whl (201 kB)
# Downloading packaging-24.2-py3-none-any.whl (65 kB)
# Downloading protobuf-5.29.5-cp38-abi3-macosx_10_9_universal2.whl (418 kB)
# Downloading pyarrow-19.0.1-cp312-cp312-macosx_12_0_x86_64.whl (32.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.1/32.1 MB 4.7 MB/s eta 0:00:0000:0100:01m
# Downloading pydantic-2.11.7-py3-none-any.whl (444 kB)
# Downloading pydantic_core-2.33.2-cp312-cp312-macosx_10_12_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 4.7 MB/s eta 0:00:00a 0:00:01
# Downloading python_dateutil-2.9.0.post0-py2.py3-none-any.whl (229 kB)
# Downloading PyYAML-6.0.2-cp312-cp312-macosx_10_9_x86_64.whl (183 kB)
# Downloading requests-2.32.4-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.3-cp312-cp312-macosx_10_13_universal2.whl (205 kB)
# Downloading idna-3.10-py3-none-any.whl (70 kB)
# Downloading rsa-4.9.1-py3-none-any.whl (34 kB)
# Downloading smmap-5.0.2-py3-none-any.whl (24 kB)
# Downloading sqlalchemy-2.0.43-cp312-cp312-macosx_10_13_x86_64.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 4.7 MB/s eta 0:00:00a 0:00:01
# Downloading sqlparse-0.5.3-py3-none-any.whl (44 kB)
# Downloading starlette-0.47.2-py3-none-any.whl (72 kB)
# Downloading anyio-4.10.0-py3-none-any.whl (107 kB)
# Downloading typing_extensions-4.14.1-py3-none-any.whl (43 kB)
# Downloading urllib3-2.5.0-py3-none-any.whl (129 kB)
# Downloading uvicorn-0.35.0-py3-none-any.whl (66 kB)
# Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Downloading blinker-1.9.0-py3-none-any.whl (8.5 kB)
# Downloading certifi-2025.8.3-py3-none-any.whl (161 kB)
# Downloading contourpy-1.3.3-cp312-cp312-macosx_10_13_x86_64.whl (293 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.59.1-cp312-cp312-macosx_10_13_x86_64.whl (2.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 4.6 MB/s eta 0:00:00a 0:00:01
# Downloading greenlet-3.2.4-cp312-cp312-macosx_11_0_universal2.whl (274 kB)
# Downloading h11-0.16.0-py3-none-any.whl (37 kB)
# Downloading itsdangerous-2.2.0-py3-none-any.whl (16 kB)
# Downloading joblib-1.5.1-py3-none-any.whl (307 kB)
# Downloading kiwisolver-1.4.9-cp312-cp312-macosx_10_13_x86_64.whl (66 kB)
# Downloading MarkupSafe-3.0.2-cp312-cp312-macosx_10_13_universal2.whl (14 kB)
# Downloading pillow-11.3.0-cp312-cp312-macosx_10_13_x86_64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 4.8 MB/s eta 0:00:00a 0:00:01
# Downloading pyasn1-0.6.1-py3-none-any.whl (83 kB)
# Downloading pyasn1_modules-0.4.2-py3-none-any.whl (181 kB)
# Downloading pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading six-1.17.0-py2.py3-none-any.whl (11 kB)
# Downloading sniffio-1.3.1-py3-none-any.whl (10 kB)
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Downloading tzdata-2025.2-py2.py3-none-any.whl (347 kB)
# Downloading werkzeug-3.1.3-py3-none-any.whl (224 kB)
# Downloading zipp-3.23.0-py3-none-any.whl (10 kB)
# Downloading mako-1.3.10-py3-none-any.whl (78 kB)
# Building wheels for collected packages: psutil
#   Building wheel for psutil (setup.py): started
#   Building wheel for psutil (setup.py): finished with status 'done'
#   Created wheel for psutil: filename=psutil-5.9.0-cp312-cp312-macosx_10_13_x86_64.whl size=237198 sha256=5df9abb989c284065c6c46b8a3d8439f038fdc02e9d58ac6e0c9e56e85b57766
#   Stored in directory: /private/var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpbuo87apc/envs/pip_cache_pkgs/wheels/86/bf/4d/f133d3cbffc7c8991cd85fec43d18ff7507b3bc9042bbfd146
# Successfully built psutil
# Installing collected packages: pytz, zipp, urllib3, tzdata, typing-extensions, threadpoolctl, sqlparse, sniffio, smmap, six, pyyaml, pyparsing, pyasn1, pyarrow, psutil, protobuf, pillow, packaging, numpy, markupsafe, markdown, kiwisolver, joblib, itsdangerous, idna, h11, greenlet, graphql-core, fonttools, cycler, cloudpickle, click, charset_normalizer, certifi, cachetools, blinker, annotated-types, werkzeug, uvicorn, typing-inspection, sqlalchemy, scipy, rsa, requests, python-dateutil, pydantic-core, pyasn1-modules, Mako, Jinja2, importlib_metadata, gunicorn, graphql-relay, gitdb, contourpy, anyio, starlette, scikit-learn, pydantic, pandas, opentelemetry-api, matplotlib, graphene, google-auth, gitpython, Flask, docker, alembic, opentelemetry-semantic-conventions, fastapi, databricks-sdk, opentelemetry-sdk, mlflow-skinny, mlflow
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73/73 [mlflow] [mlflow]w]mlflow-skinny]]dk]onventions]
# Successfully installed Flask-3.1.1 Jinja2-3.1.6 Mako-1.3.10 alembic-1.16.4 annotated-types-0.7.0 anyio-4.10.0 blinker-1.9.0 cachetools-5.5.2 certifi-2025.8.3 charset_normalizer-3.4.3 click-8.2.1 cloudpickle-3.1.1 contourpy-1.3.3 cycler-0.12.1 databricks-sdk-0.63.0 docker-7.1.0 fastapi-0.116.1 fonttools-4.59.1 gitdb-4.0.12 gitpython-3.1.45 google-auth-2.40.3 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 greenlet-3.2.4 gunicorn-23.0.0 h11-0.16.0 idna-3.10 importlib_metadata-8.7.0 itsdangerous-2.2.0 joblib-1.5.1 kiwisolver-1.4.9 markdown-3.8.2 markupsafe-3.0.2 matplotlib-3.10.5 mlflow-2.21.3 mlflow-skinny-2.21.3 numpy-2.3.1 opentelemetry-api-1.36.0 opentelemetry-sdk-1.36.0 opentelemetry-semantic-conventions-0.57b0 packaging-24.2 pandas-2.3.0 pillow-11.3.0 protobuf-5.29.5 psutil-5.9.0 pyarrow-19.0.1 pyasn1-0.6.1 pyasn1-modules-0.4.2 pydantic-2.11.7 pydantic-core-2.33.2 pyparsing-3.2.3 python-dateutil-2.9.0.post0 pytz-2025.2 pyyaml-6.0.2 requests-2.32.4 rsa-4.9.1 scikit-learn-1.6.1 scipy-1.16.0 six-1.17.0 smmap-5.0.2 sniffio-1.3.1 sqlalchemy-2.0.43 sqlparse-0.5.3 starlette-0.47.2 threadpoolctl-3.6.0 typing-extensions-4.14.1 typing-inspection-0.4.1 tzdata-2025.2 urllib3-2.5.0 uvicorn-0.35.0 werkzeug-3.1.3 zipp-3.23.0
#
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate mlflow-c73ae8786f87d613ef17c0fe652494c39f6dff36-8f29c64111ad37fd5ede73b43578e91380b4e0f0
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate
# 2025/08/18 19:19:25 INFO mlflow.utils.environment: === Running command '['bash', '-c', 'source /opt/anaconda3/bin/../etc/profile.d/conda.sh && conda activate mlflow-c73ae8786f87d613ef17c0fe652494c39f6dff36-8f29c64111ad37fd5ede73b43578e91380b4e0f0 1>&2 && python -c ""']'
# 2025/08/18 19:19:26 INFO mlflow.utils.environment: === Running command '['bash', '-c', 'source /opt/anaconda3/bin/../etc/profile.d/conda.sh && conda activate mlflow-c73ae8786f87d613ef17c0fe652494c39f6dff36-8f29c64111ad37fd5ede73b43578e91380b4e0f0 1>&2 && python /opt/anaconda3/envs/mlflow_env/lib/python3.12/site-packages/mlflow/pyfunc/_mlflow_pyfunc_backend_predict.py --model-uri file:///var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpc3ebtcf6/model --content-type json --input-path /var/folders/p_/237vh0m92ws4lbbnrhz3b1rr0000gn/T/tmpdv8aq5hx/input.json']'
# {"predictions": [145.26639040933335]}

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 1.6.1
